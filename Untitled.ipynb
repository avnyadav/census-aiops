# %%
from census_consumer_complaint_component.component import get_census_consumer_complaint_pipeline_component

# %%
from census_consumer_complaint_orchestrator.interactive_context_runner import CensusConsumerInteractiveContext

# %%
cx=CensusConsumerInteractiveContext().get_interactive_context()

# %%
component = get_census_consumer_complaint_pipeline_component()
# Out:
# WARNING:absl:`custom_executor_spec` is deprecated. Please customize component directly.
# WARNING:absl:`transformed_examples` is deprecated. Please use `examples` instead.
# save model dir:/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/saved_models

# %%
cx.run(component[0])
# Out:
# ...
# Extracting file in  /home/avnish/census_consumer_project/census_consumer_complaint/zip_to_csv
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: RemoteZipCsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 14
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/RemoteZipCsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
# ...

# %%
cx.run(component[1])
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 2
#     outputs:
#         statistics: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 2
#         type_id: 16
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/StatisticsGen/statistics/2"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "statistics"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "StatisticsGen"
#           }
#         }
#         custom_properties {
# ...

# %%
cx.run(component[2])
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 3
#     outputs:
#         schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 3
#         type_id: 18
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/SchemaGen/schema/3"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "SchemaGen"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
# ...

# %%
cx.run(component[3])
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 4
#     outputs:
#         anomalies: Channel(
#             type_name: ExampleAnomalies
#             artifacts: [Artifact(artifact: id: 4
#         type_id: 20
#         uri: "/home/avnish/census_consumer_project/census_consumer_complaint/census_consumer_complaint_data/census_consumer_complaint/artifact/ExampleValidator/anomalies/4"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "anomalies"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "ExampleValidator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
# ...

# %%
cx.run(component[4])
# Out:
# Columns: dict_keys(['Company', 'Company public response', 'Company response to consumer', 'Complaint ID', 'Consumer complaint narrative', 'Consumer consent provided?', 'Consumer disputed?', 'Date received', 'Date sent to company', 'Issue', 'Product', 'State', 'Sub-issue', 'Sub-product', 'Submitted via', 'Tags', 'Timely response?', 'ZIP code'])
# <class 'tensorflow.python.framework.ops.Tensor'>
# Column: Tensor("inputs_16_copy:0", shape=(None, 1), dtype=string) has been updated: False
# <class 'tensorflow.python.framework.sparse_tensor.SparseTensor'>
# Column: Tensor("SparseToDense:0", shape=(None, 1), dtype=string) has been updated: True
# <class 'tensorflow.python.framework.ops.Tensor'>
# Column: Tensor("inputs_4_copy:0", shape=(None, 1), dtype=string) has been updated: False
# <class 'tensorflow.python.framework.sparse_tensor.SparseTensor'>
# Column: Tensor("SparseToDense_1:0", shape=(None, 1), dtype=string) has been updated: True
# <class 'tensorflow.python.framework.ops.Tensor'>
# ...

# %%
cx.run(component[5])
# Out:
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# building model with columnCompany response to consumer_xf
# building model with columnConsumer complaint narrative_xf
# building model with columnIssue_xf
# building model with columnProduct_xf
# building model with columnState_xf
# building model with columnSub-product_xf
#    1/1000 [..............................] - ETA: 3:10 - loss: 0.7323 - binary_accuracy: 0.7800
# /home/avnish/census_consumer_project/census_consumer_complaint/venv/lib/python3.7/site-packages/keras/engine/functional.py:559: UserWarning: Input dict contained keys ['Consumer complaint narrative_xf'] which did not match any model input. They will be ignored by the model.
# ...

# %%
cx.run(component[6])
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 7
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: []
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_blessing: Channel(
#             type_name: ModelBlessing
#             artifacts: []
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
